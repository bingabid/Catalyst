# %%
import os
import numpy as np
import seaborn as sns
from configs import ModelConfig
import matplotlib.pyplot as plt

# %% [markdown]
# ## Observation 1 Plots

# %%
model = 'densenet101'
in_dataset = 'CIFAR-10'
out_dataset = 'dtd'

# model = 'mobilenetv2_imagenet' 
# model = 'resnet_imagenet34'
# model = 'resnet_imagenet50'
# in_dataset = 'ImageNet-1K'
# out_dataset = 'imagenet_dtd'

# %% [markdown]
# #### Load ID Features Statistics

# %%
base_directory_name = f"{model}/{in_dataset}/"
model_checkpoint_directory = os.path.join(ModelConfig.model_checkpoint_directory, base_directory_name)
model_statistics_directory = os.path.join(ModelConfig.model_statistics_directory, base_directory_name)
print(model_statistics_directory)
in_model_statistics_directory = os.path.join(model_statistics_directory, f"{in_dataset}")
in_statistics_file_name = os.path.join(in_model_statistics_directory, f"in_{in_dataset}")
print(in_statistics_file_name)

# %%
in_std_fname = in_statistics_file_name + '_std.npy'
in_maxi_fname = in_statistics_file_name + '_maxi.npy'
in_mean_fname = in_statistics_file_name + '_mean.npy'
in_labels_fname = in_statistics_file_name + '_labels.npy'

in_std = np.load(in_std_fname)
in_maxi = np.load(in_maxi_fname)
in_mean = np.load(in_mean_fname)
in_labels = np.load(in_labels_fname)

# %%
# idx = 5
# print(f"mean: {in_mean[:1, idx:idx + 5]}")
# print(f"std:  {in_std[:1,  idx:idx + 5]}")
# print(f"max:  {in_maxi[:1, idx:idx + 5]}")

# %% [markdown]
# #### Load OOD Feature Statistics

# %%
out_model_statistics_directory = os.path.join(model_statistics_directory, f"{out_dataset}")
out_statistics_file_name = os.path.join(out_model_statistics_directory, f"out_{out_dataset}")
print(out_statistics_file_name)

out_std_fname = out_statistics_file_name + '_std.npy'
out_maxi_fname = out_statistics_file_name + '_maxi.npy'
out_mean_fname = out_statistics_file_name + '_mean.npy'
out_std = np.load(out_std_fname)
out_maxi = np.load(out_maxi_fname)
out_mean = np.load(out_mean_fname)

# %%
# idx = 5
# print(f"mean: {out_mean[:1, idx:idx + 5]}")
# print(f"std:  {out_std[:1,  idx:idx + 5]}")
# print(f"max:  {out_maxi[:1, idx:idx + 5]}")

# %%
x_in_mean = in_mean.mean(0)
x_out_mean = out_mean.mean(0)

# idx = np.argsort(x_in_mean)
# x_in_mean = x_in_mean[idx]
# x_out_mean = x_out_mean[idx]

# x_in_mean.sort()
# x_out_mean.sort()


plt.figure(figsize=(10, 4))
plt.plot(x_in_mean, label='ID')
plt.plot(x_out_mean, label='OOD')


plt.title('μ(x)')
plt.xlabel('units')
plt.ylabel('act')
plt.legend(loc = 'best')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
x_in_std = in_std.mean(0)
x_out_std = out_std.mean(0)

# idx = np.argsort(x_in_std)
# x_in_std = x_in_std[idx]
# x_out_std = x_out_std[idx]

# x_in_std.sort()
# x_out_std.sort()


plt.figure(figsize=(10, 4))
plt.plot(x_in_std, label='ID')
plt.plot(x_out_std, label='OOD')


plt.title('σ(x)')
plt.xlabel('units')
plt.ylabel('act')
plt.legend(loc = 'best')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
x_in_maxi = in_maxi.mean(0)
x_out_maxi = out_maxi.mean(0)

# idx = np.argsort(x_in_maxi)
# x_in_maxi = x_in_maxi[idx]
# x_out_maxi = x_out_maxi[idx]

# x_in_maxi.sort()
# x_out_maxi.sort()


plt.figure(figsize=(10, 4))
plt.plot(x_in_maxi, label='ID')
plt.plot(x_out_maxi, label='OOD')


plt.title('m(x)')
plt.xlabel('units')
plt.ylabel('act')
plt.legend(loc = 'best')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

axes[0].plot(x_in_mean, label='ID')
axes[0].plot(x_out_mean, label='OOD')
axes[0].set_title('μ(x)')
axes[0].legend(loc = 'best')
axes[0].grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)

axes[1].plot(x_in_std, label='ID')
axes[1].plot(x_out_std, label='OOD')
axes[1].set_title('σ(x)')
axes[1].legend(loc = 'best')
axes[1].grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)

axes[2].plot(x_in_maxi, label='ID')
axes[2].plot(x_out_maxi, label='OOD')
axes[2].set_title('m(x)')
axes[2].legend(loc = 'best')
axes[2].grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Observation 3 Plots

# %%
model = 'densenet101'
in_dataset = 'CIFAR-100'
out_dataset = 'dtd'

# model = 'mobilenetv2_imagenet' 
# model = 'resnet_imagenet34'
# model = 'resnet_imagenet50'
# in_dataset = 'ImageNet-1K'
# out_dataset = 'imagenet_dtd'

# %%
base_directory_name = f"{model}/{in_dataset}/"
model_result_directory = os.path.join(ModelConfig.ood_evaluation_directory, base_directory_name)
model_result_directory = os.path.join(model_result_directory, f"DomAct/")
in_avg_score_fname =  os.path.join(model_result_directory, f"avg/{model}_{in_dataset}_in_energy_score.txt")
in_max_score_fname =  os.path.join(model_result_directory, f"max/{model}_{in_dataset}_in_energy_score.txt")
print(in_avg_score_fname)

in_avg_score = np.loadtxt(in_avg_score_fname)
in_max_score = np.loadtxt(in_max_score_fname)

# %%
sns.kdeplot(in_avg_score, label='avg', fill=True, linewidth=2)
sns.kdeplot(in_max_score, label='max', fill=True, linewidth=2)

plt.title('ID-OOD Density')
plt.xlabel('score')
plt.ylabel('density')
plt.legend(loc = 'best')
# plt.xticks([])
# plt.yticks([])
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
base_directory_name = f"{model}/{in_dataset}/"
model_result_directory = os.path.join(ModelConfig.ood_evaluation_directory, base_directory_name)
model_result_directory = os.path.join(model_result_directory, f"DomAct/")
out_avg_score_fname =  os.path.join(model_result_directory, f"avg/{model}_{out_dataset}_out_energy_score.txt")
out_max_score_fname =  os.path.join(model_result_directory, f"max/{model}_{out_dataset}_out_energy_score.txt")
print(out_avg_score_fname)

out_avg_score = np.loadtxt(out_avg_score_fname)
out_max_score = np.loadtxt(out_max_score_fname)

# %%
sns.kdeplot(out_avg_score, label='avg', fill=True, linewidth=2)
sns.kdeplot(out_max_score, label='max', fill=True, linewidth=2)

plt.title('ID-OOD Density')
plt.xlabel('score')
plt.ylabel('density')
plt.legend(loc = 'best')
# plt.xticks([])
# plt.yticks([])
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# avg score
sns.kdeplot(in_avg_score, label='μ(x)', fill=True, ax=axes[0])
sns.kdeplot(in_max_score, label='m(x)', fill=True, ax=axes[0])
axes[0].set_title('ID')
axes[0].set_xlabel('scores')
axes[0].set_ylabel('density')
axes[0].legend(loc = 'best')
axes[0].grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)

# max score
sns.kdeplot(out_avg_score, label='μ(x)', fill=True, ax=axes[1])
sns.kdeplot(out_max_score, label='m(x)', fill=True, ax=axes[1])
axes[1].set_title('OOD')
axes[1].set_xlabel('scores')
axes[1].set_ylabel('density')
axes[1].legend(loc = 'best')
axes[1].grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Observation 2 Plots

# %%
# model = 'densenet101'
# in_dataset = 'CIFAR-100'
# out_dataset = 'dtd'

# model = 'mobilenetv2_imagenet' 
# model = 'resnet_imagenet34'
model = 'resnet_imagenet50'
in_dataset = 'ImageNet-1K'
out_dataset = 'imagenet_dtd'

# %%
base_directory_name = f"{model}/{in_dataset}/"
model_checkpoint_directory = os.path.join(ModelConfig.model_checkpoint_directory, base_directory_name)
model_statistics_directory = os.path.join(ModelConfig.model_statistics_directory, base_directory_name)
print(model_statistics_directory)
in_model_statistics_directory = os.path.join(model_statistics_directory, f"{in_dataset}")
in_statistics_file_name = os.path.join(in_model_statistics_directory, f"in_{in_dataset}")
print(in_statistics_file_name)

# %%
in_std_fname = in_statistics_file_name + '_std.npy'
in_maxi_fname = in_statistics_file_name + '_maxi.npy'
in_mean_fname = in_statistics_file_name + '_mean.npy'
in_labels_fname = in_statistics_file_name + '_labels.npy'

in_std = np.load(in_std_fname)
in_maxi = np.load(in_maxi_fname)
in_mean = np.load(in_mean_fname)
in_labels = np.load(in_labels_fname)

# %%
out_model_statistics_directory = os.path.join(model_statistics_directory, f"{out_dataset}")
out_statistics_file_name = os.path.join(out_model_statistics_directory, f"out_{out_dataset}")
print(out_statistics_file_name)

out_std_fname = out_statistics_file_name + '_std.npy'
out_maxi_fname = out_statistics_file_name + '_maxi.npy'
out_mean_fname = out_statistics_file_name + '_mean.npy'
out_std = np.load(out_std_fname)
out_maxi = np.load(out_maxi_fname)
out_mean = np.load(out_mean_fname)

# %%
#avg
x_in_mean = in_mean.mean(0)
x_out_mean = out_mean.mean(0)
delta_mean = x_in_mean - x_out_mean

#std
x_in_std = in_std.mean(0)
x_out_std = out_std.mean(0)
delta_std = x_in_std - x_out_std

#max
x_in_maxi = in_maxi.mean(0)
x_out_maxi = out_maxi.mean(0)
delta_maxi = x_in_maxi - x_out_maxi

# %%
#avg+std
x_in_mean_std = in_mean + in_std
x_out_mean_std = out_mean + out_std
x_in_mean_std_mean = x_in_mean_std.mean(0)
x_out_mean_std_mean = x_out_mean_std.mean(0)
delta_mean_std = x_in_mean_std_mean - x_out_mean_std_mean

# %%
# idx = np.argsort(delta_mean)
# delta_maxi = delta_maxi[idx]
# delta_mean = delta_mean[idx]
# delta_mean_std = delta_mean_std[idx]

# %%
# delta_maxi.sort()
# delta_mean.sort()
# delta_mean_std.sort()
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(delta_mean_std, label=r'$\Delta_{\mu,\sigma}$')
axes[0].plot(delta_mean, label=r'$\Delta_{\mu}$')
axes[0].set_title(r'$\Delta_{\mu,\sigma} \geq \Delta_{\mu}$')
axes[0].legend(loc = 'best')
axes[0].grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)

axes[1].plot(delta_maxi, label=r'$\Delta_{m}$')
axes[1].plot(delta_mean, label=r'$\Delta_{\mu}$')
axes[1].set_title(r'$\Delta_{m} \geq \Delta_{\mu}$')
axes[1].legend(loc = 'best')
axes[1].grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)



plt.tight_layout()
plt.show()

# %% [markdown]
# ## Median Entropy

# %%
model = 'densenet101'
in_dataset = 'CIFAR-100'
out_dataset = 'dtd'

# model = 'mobilenetv2_imagenet' 
# model = 'resnet_imagenet34'
# model = 'resnet_imagenet50'
# in_dataset = 'ImageNet-1K'
# out_dataset = 'imagenet_dtd'

# %%
base_directory_name = f"{model}/{in_dataset}/"
model_checkpoint_directory = os.path.join(ModelConfig.model_checkpoint_directory, base_directory_name)
model_statistics_directory = os.path.join(ModelConfig.model_statistics_directory, base_directory_name)
print(model_statistics_directory)
in_model_statistics_directory = os.path.join(model_statistics_directory, f"{in_dataset}")
in_statistics_file_name = os.path.join(in_model_statistics_directory, f"in_{in_dataset}")
print(in_statistics_file_name)

in_median_fname = in_statistics_file_name + '_median.npy'
in_entropy_fname = in_statistics_file_name + '_entropy.npy'

in_median = np.load(in_median_fname)
in_entropy = np.load(in_entropy_fname)

out_model_statistics_directory = os.path.join(model_statistics_directory, f"{out_dataset}")
out_statistics_file_name = os.path.join(out_model_statistics_directory, f"out_{out_dataset}")
print(out_statistics_file_name)

out_median_fname = out_statistics_file_name + '_median.npy'
out_entropy_fname = out_statistics_file_name + '_entropy.npy'

out_median = np.load(out_median_fname)
out_entorpy = np.load(out_entropy_fname)

# %%
# idx = np.argsort(x_in_mean)
# x_in_mean = x_in_mean[idx]
# x_out_mean = x_out_mean[idx]

# %%
#median
x_in_median = in_median.mean(0)
x_out_median = out_median.mean(0)

# idx = np.argsort(x_in_median)
# x_in_median = x_in_median[idx]
# x_out_median = x_out_median[idx]

#entropy
x_in_entropy = in_entropy.mean(0)
x_out_entropy = out_entorpy.mean(0)

# idx = np.argsort(x_in_entropy)
# x_in_entropy = x_in_entropy[idx]
# x_out_entropy = x_out_entropy[idx]


#sort
# x_in_median.sort()
# x_out_median.sort()
# x_in_entropy.sort()
# x_out_entropy.sort()

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(x_in_median, label=r'ID')
axes[0].plot(x_out_median, label=r'OOD')
axes[0].set_title(r'Median')
axes[0].legend(loc = 'best')
axes[0].grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)

axes[1].plot(x_in_entropy, label=r'ID')
axes[1].plot(x_out_entropy, label=r'OOD')
axes[1].set_title(r'Entropy')
axes[1].legend(loc = 'best')
axes[1].grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)



plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plots Statistics

# %% [markdown]
# #### (a) Avg Activations

# %%
# mean activations
x_in_mean = in_mean.mean(0)
x_out_mean = out_mean.mean(0)

# %%
plt.figure(figsize=(10, 4))
plt.plot(x_in_mean, label='ID')
plt.plot(x_out_mean, label='OOD')


plt.title('Avg Act')
plt.xlabel('units')
plt.ylabel('act')
plt.legend(loc = 'best')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
x_in_mean.sort()
x_out_mean.sort()

plt.figure(figsize=(10, 4))
plt.plot(x_in_mean, label='ID')
plt.plot(x_out_mean, label='OOD')

plt.title('Avg Act')
plt.xlabel('units')
plt.ylabel('act')
plt.legend(loc = 'best')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()

plt.show()

# %% [markdown]
# #### (b) Dominant Activations

# %%
in_std = np.load(in_std_fname)
in_maxi = np.load(in_maxi_fname)
in_mean = np.load(in_mean_fname)
in_labels = np.load(in_labels_fname)

out_std = np.load(out_std_fname)
out_maxi = np.load(out_maxi_fname)
out_mean = np.load(out_mean_fname)

# %%
# dominant activations
in_maxi[in_maxi<1.0] = 0.0
out_maxi[out_maxi<1.0] = 0.0
x_in_maxi = in_maxi.mean(0)
x_out_maxi = out_maxi.mean(0)

plt.figure(figsize=(10, 4))
plt.plot(x_in_maxi, label='ID')
plt.plot(x_out_maxi, label='OOD')


plt.title('Dominant Act')
plt.xlabel('units')
plt.ylabel('act')
plt.legend(loc = 'best')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()

plt.show()

x_in_maxi.sort()
x_out_maxi.sort()

plt.figure(figsize=(10, 4))
plt.plot(x_in_maxi, label='ID')
plt.plot(x_out_maxi, label='OOD')


plt.title('Dominant Act')
plt.xlabel('units')
plt.ylabel('act')
plt.legend(loc = 'best')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
# dominant activations
# in_maxi[in_maxi<2.0] = 0.0
# out_maxi[out_maxi<2.0] = 0.0
x_in_maxi = in_maxi.mean(0)
x_out_maxi = out_maxi.mean(0)

plt.figure(figsize=(10, 4))
plt.plot(x_in_maxi, label='ID')
plt.plot(x_out_maxi, label='OOD')


plt.title('Dominant Act')
plt.xlabel('units')
plt.ylabel('act')
plt.legend(loc = 'best')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()

plt.show()

x_in_maxi.sort()
x_out_maxi.sort()

plt.figure(figsize=(10, 4))
plt.plot(x_in_maxi, label='ID')
plt.plot(x_out_maxi, label='OOD')


plt.title('Dominant Act')
plt.xlabel('units')
plt.ylabel('act')
plt.legend(loc = 'best')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
x_in_maxi = in_maxi.mean(0)
x_out_maxi = out_maxi.mean(0)

x_in_maxi[x_in_maxi<=2.0] = 0
x_out_maxi[x_out_maxi<=2.0] = 0

x_in_maxi = x_in_maxi.clip(max = 4.0)
x_out_maxi = x_out_maxi.clip(max = 4.0)

c_in = (x_in_maxi <= 0).sum()
c_out = ((x_out_maxi <= 0).sum())
print(f"c_in: {c_in}, c_out:{c_out}")

plt.figure(figsize=(10, 4))
plt.plot(x_in_maxi, label='ID')
plt.plot(x_out_maxi, label='OOD')

plt.title('Dominant Act')
plt.xlabel('units')
plt.ylabel('act')
plt.legend(loc = 'best')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()

plt.show()

x_in_maxi.sort()
x_out_maxi.sort()

plt.figure(figsize=(10, 4))
plt.plot(x_in_maxi, label='ID')
plt.plot(x_out_maxi, label='OOD')

plt.title('Dominant Act')
plt.xlabel('units')
plt.ylabel('act')
plt.legend(loc = 'best')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
x_in_maxi = in_maxi.mean(0)
x_out_maxi = out_maxi.mean(0)

x_in_maxi = x_in_maxi * (-1.0)
x_in_maxi = x_in_maxi.clip(max = -2.0)
x_in_maxi = x_in_maxi * (-1.0)

x_out_maxi = x_out_maxi * (-1.0)
x_out_maxi = x_out_maxi.clip(max = -2.0)
x_out_maxi = x_out_maxi * (-1.0)

x_in_maxi = x_in_maxi.clip(max = 2.6)
x_out_maxi = x_out_maxi.clip(max = 2.6)

plt.figure(figsize=(10, 4))
plt.plot(x_in_maxi, label='ID')
plt.plot(x_out_maxi, label='OOD')

plt.title('Dominant Act')
plt.xlabel('units')
plt.ylabel('act')
plt.legend(loc = 'best')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()

plt.show()

x_in_maxi.sort()
x_out_maxi.sort()

plt.figure(figsize=(10, 4))
plt.plot(x_in_maxi, label='ID')
plt.plot(x_out_maxi, label='OOD')

plt.title('Dominant Act')
plt.xlabel('units')
plt.ylabel('act')
plt.legend(loc = 'best')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()

plt.show()

# %% [markdown]
# #### (c) Standard Deviation

# %%
# standard deviation
x_in_std = in_std.mean(0)
x_out_std = out_std.mean(0)

# %%
plt.figure(figsize=(10, 4))
plt.plot(x_in_std, label='ID')
plt.plot(x_out_std, label='OOD')

plt.title('Standard Deviation')
plt.xlabel('units')
plt.ylabel('act')
plt.legend(loc = 'best')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
x_in_std.sort()
x_out_std.sort()
plt.figure(figsize=(10, 4))
plt.plot(x_in_std, label='ID')
plt.plot(x_out_std, label='OOD')

plt.title('Standard Deviation')
plt.xlabel('units')
plt.ylabel('act')
plt.legend(loc = 'best')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
#### run here

# %% [markdown]
# ### Plots Comparative Statistics: delta values

# %%
# avg 
x_in_mean = in_mean.mean(0)
x_out_mean = out_mean.mean(0)
delta_mean = x_in_mean - x_out_mean

# %%
# std
x_in_std = in_std.mean(0)
x_out_std = out_std.mean(0)
delta_std = x_in_std - x_out_std

# %%
# dominant
x_in_maxi = in_maxi.mean(0)
x_out_maxi = out_maxi.mean(0)
delta_maxi = x_in_maxi - x_out_maxi

# %%
print(f" avg dealta_mean: {delta_mean.mean()}, avg delta_std: {delta_std.mean()}, avg delta_maxi: {delta_maxi.mean()}")

# %% [markdown]
# #### (a) Raw Delta Comparision

# %%
plt.figure(figsize=(10, 4))
plt.plot(delta_maxi, label='max')
# plt.plot(delta_std, label='std')
plt.plot(delta_mean, label='mean')

plt.title('')
plt.xlabel('units')
plt.ylabel('act')
plt.legend()
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)

plt.show()

# %% [markdown]
# #### (b) Sorted Delta Comparision

# %%
x_delta_maxi = sorted(delta_maxi)
x_delta_std = sorted(delta_std)
x_delta_mean = sorted(delta_mean)
plt.figure(figsize=(10, 4))
plt.plot(x_delta_maxi, label='max')
plt.plot(x_delta_std, label='std')
plt.plot(x_delta_mean, label='avg')


plt.title('Delta')
plt.xlabel('Units')
plt.ylabel('Value')
plt.legend(loc = 'best')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# one std away from mean
in_mean_std = in_mean + in_std
out_mean_std = out_mean + out_std
delta_mean_std = in_mean_std.mean(0) - out_mean_std.mean(0)

# %%
x_delta_maxi = sorted(delta_maxi)
x_delta_mean_std = sorted(delta_mean_std)
x_delta_mean = sorted(delta_mean)
plt.figure(figsize=(10, 4))
plt.plot(x_delta_maxi, label='max')
plt.plot(x_delta_mean_std, label='avg+std')
plt.plot(x_delta_mean, label='avg')


plt.title('Delta')
plt.xlabel('Units')
plt.ylabel('Value')
plt.legend(loc = 'best')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### (b) Indexed Sorted Delta Comparision

# %%
idx = np.argsort(delta_maxi)
delta_mean = delta_mean[idx]
delta_maxi = delta_maxi[idx]
delta_mean_std = delta_mean_std[idx]

plt.figure(figsize=(10, 4))
plt.plot(delta_maxi, label='max')
plt.plot(delta_mean_std, label='avg+std')
plt.plot(delta_mean, label='avg')


plt.title('Delta')
plt.xlabel('Units')
plt.ylabel('Value')
plt.legend(loc = 'best')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
delta_mean.sort()
delta_maxi.sort()
delta_mean_std.sort()


plt.figure(figsize=(10, 4))
plt.plot(delta_maxi, label='max')
plt.plot(delta_mean_std, label='avg+std')
plt.plot(delta_mean, label='avg')


plt.title('Delta')
plt.xlabel('Units')
plt.ylabel('Value')
plt.legend(loc = 'best')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot Density Distribution

# %%
model_result_directory = os.path.join(ModelConfig.ood_evaluation_directory, base_directory_name)
model_result_directory = os.path.join(model_result_directory, f"DomAct/")
# print(model_result_directory)

# %% [markdown]
# #### (a) Using 'Avg' Energy Scores

# %%
# load 'avg' energy score
in_avg_score_fname =  os.path.join(model_result_directory, f"avg/{model}_{in_dataset}_in_energy_score.txt")
out_avg_score_fname =  os.path.join(model_result_directory, f"avg/{model}_{out_dataset}_out_energy_score.txt")

in_avg_score = np.loadtxt(in_avg_score_fname)
out_avg_score = np.loadtxt(out_avg_score_fname)

# %%
sns.kdeplot(in_avg_score, label='in', fill=True, linewidth=2)
sns.kdeplot(out_avg_score, label='ood', fill=True, linewidth=2)

plt.title('ID-OOD Density')
plt.xlabel('value')
plt.ylabel('density')
plt.legend()
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### (b) Using 'Dominant' Energy Scores

# %%
# load 'max' energy scores
in_max_score_fname =  os.path.join(model_result_directory, f"max/{model}_{in_dataset}_in_energy_score.txt")
out_max_score_fname =  os.path.join(model_result_directory, f"max/{model}_{out_dataset}_out_energy_score.txt")

in_max_score = np.loadtxt(in_max_score_fname)
out_max_score = np.loadtxt(out_max_score_fname)

# %%
sns.kdeplot(in_max_score, label='in', fill=True, linewidth=2)
sns.kdeplot(out_max_score, label='ood', fill=True, linewidth=2)

plt.title('ID-OOD Density')
plt.xlabel('value')
plt.ylabel('density')
plt.legend()
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### (c) Juxtaposed Densisty Overlap Comparison

# %%
plt.figure(figsize=(10, 4))

sns.kdeplot(in_avg_score, label='in', fill=True, linewidth=2, color='green')
sns.kdeplot(out_avg_score, label='ood', fill=True, linewidth=2, color='red')

plt.title('')
plt.xlabel('scores')
plt.ylabel('density')
plt.legend()
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 4))

sns.kdeplot(in_max_score, label='in', fill=True, linewidth=2, color='green')
sns.kdeplot(out_max_score, label='ood', fill=True, linewidth=2, color='red')

plt.title('')
plt.xlabel('scores')
plt.ylabel('density')
plt.legend()
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# avg score
sns.kdeplot(in_avg_score, label='in', fill=True, ax=axes[0], color='green')
sns.kdeplot(out_avg_score, label='ood', fill=True, ax=axes[0], color='red')
axes[0].set_title('')
axes[0].set_xlabel('scores')
axes[0].set_ylabel('density')
axes[0].legend()
axes[0].grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)

# max score
sns.kdeplot(in_max_score, label='in', fill=True, ax=axes[1], color='green')
sns.kdeplot(out_max_score, label='ood', fill=True, ax=axes[1], color='red')
axes[1].set_title('')
axes[1].set_xlabel('scores')
axes[1].set_ylabel('density')
axes[1].legend()
axes[1].grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.3)

plt.tight_layout()
plt.show()
